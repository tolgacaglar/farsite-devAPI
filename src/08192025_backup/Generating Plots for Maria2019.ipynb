# %% [markdown]
# # Generating plots for Maria2019

# %%
from dsfunctions import forward_pass, forward_pass_nsteps, sample_windspeed, sample_winddirection, sample_geometry
from dsfunctions import plot_matrix, plot_matrix_ensemble, align_geoms, interpolate_geom, get_observation, plot_geometry
from dsfunctions import geom_to_vector, reproject_geom, validate_geom
from dsfunctions import forward_pass_farsite

import farsiteutils_v2 as futils
import datetime
import uuid

import numpy as np
from matplotlib import pyplot as plt

import contextily as ctx

import pickle
from shapely.geometry import Polygon
from tqdm import tqdm

# %% [markdown]
# ## Load data

# %%
import pickle

# with open('./Maria2019_results_22082024_vsz1000_wsz1.pkl', 'rb') as f:
    # data = pickle.load(f)

with open('/home/tcaglar/farsite-devAPI/data/Maria2019_results_17092024_vsz100_wsz100.pkl', 'rb') as f:
    data = pickle.load(f)


adjusted_geom_lst = data['adjusted_geom']
description = 'Maria2019'
tfin = 10

# %% [markdown]
# ## Load the observations

# %%
# MAria Fire wind values
# Windspeed and Wind direction that were used live
wslst = [11, 18, 18, 25, 17, 22, 15, 12, 14, 14, 14]
wdlst = [37, 48, 48, 44, 16, 29, 19, 24, 22, 21, 20]

# # # Bridge fire wind values
# wslst = [15]*(tfin)
# wdlst = [270]*(tfin)

# # River fire wind values
# wslst = [15]*(tfin)
# wdlst = [215]*(tfin)

observations = []
timestamps = []
sampled_wslst = []
sampled_wdlst = []

for tix in range(10):
    obs, ts = get_observation(description, tix)
    observations.append(obs)
    timestamps.append(ts)

# %% [markdown]
# ## Generate estimated ignition

# %%
# Maria ignition
ignition_timepoint = timestamps[0].replace(hour=18, minute=13)
x,y = (-2084217.1484733422, 1503560.461310427)
width = 200
xshift = 2000
yshift = 1500


# # Bridge2021 ignition
# ignition_timepoint = timestamps[0].replace(hour=12, minute=53)

# River2021 ignition
# ignition_timepoint = timestamps[0].replace(hour=14, minute=0)
# x,y = x,y = observations[0].centroid.x, observations[0].centroid.y
# width = 100
# xshift = -1200
# yshift = -2000

x += xshift
y+= yshift
ignition = Polygon([(x-width, y), (x, y), (x,y-width), (x-width, y-width)])

# %% [markdown]
# ## Plot ignition + perimeters

# %%
fig, ax = plt.subplots(1,1, figsize=(4,4), dpi=200)

plot_geometry(reproject_geom(ignition), ax=ax, color='red')
for i in range(tfin):
    geom, timestamp = get_observation(description, i)
    plot_geometry(reproject_geom(geom), ax=ax, label=timestamp, color=(1,0,0,1-i/10))

    if i < (tfin-1):
        print(f'{timestamp - timestamps[0]}, {timestamps[i+1]-timestamps[i]}')
    else:
        print(f'{timestamp - timestamps[0]}')

# Maria boundaries
ax.set_xlim(-13259480.899793554, -13248356.055776488)
ax.set_ylim(4066612.9682816155, 4075471.350794237)

# # Bridge boundaries
# ax.set_xlim(-2.1260e6, -2.1235e6)
# ax.set_ylim(2.0470e6, 2.0485e6)

# River boundaries
# ax.set_xlim(-2.1260e6, -2.1235e6)
# ax.set_ylim(2.0470e6, 2.0485e6)

ctx.add_basemap(ax=ax, source=ctx.providers.OpenStreetMap.Mapnik)
# Out:
# 0 days 00:00:00, 0 days 00:21:11
# 0 days 00:21:11, 0 days 00:33:11
# 0 days 00:54:22, 0 days 00:25:11
# 0 days 01:19:33, 0 days 00:26:11
# 0 days 01:45:44, 0 days 02:08:05
# 0 days 03:53:49, 0 days 00:17:00
# 0 days 04:10:49, 0 days 00:41:00
# 0 days 04:51:49, 0 days 00:25:00
# 0 days 05:16:49, 0 days 00:18:00
# 0 days 05:34:49

# %% [markdown]
# ## Model output without data assimilation
#
# ### Calculate

# %%
no_ds_outputs = [ignition]
for tix in tqdm(range(tfin-1)):
    ws = wslst[tix]
    wd = wdlst[tix]
    dt = timestamps[tix+1]-timestamps[tix]
    model_geom = forward_pass_farsite(no_ds_outputs[-1],
                                     params = {'windspeed': ws,
                                               'winddirection': wd,
                                               'dt': dt,
                                               'description': description})
    no_ds_outputs.append(model_geom)
# Out:
#   0%|          | 0/9 [00:00<?, ?it/s]
# !!Caution!! Path /home/jovyan/data/dftable_06032023.pkl not found! Cannot choose ignition!!
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-475e29679ebe> in <module>
#       4     wd = wdlst[tix]
#       5     dt = timestamps[tix+1]-timestamps[tix]
# ----> 6     model_geom = forward_pass_farsite(no_ds_outputs[-1],
#       7                                      params = {'windspeed': ws,
#       8                                                'winddirection': wd,
#
# ~/farsite-devAPI/src/dsfunctions.py in forward_pass_farsite(poly, params)
#     383     # Create handles for simulation
#     384     fp = futils.FilePaths('/home/jovyan/data/')
# --> 385     usr = futils.User(fp, description)
#     386
#     387     initialidx = uuid.uuid4().hex
#
# ~/farsite-devAPI/src/farsiteutils_v2.py in __init__(self, fp, description)
#     304
#     305         # Setup the main components
# --> 306         self.__setup()
#     307
#     308
#
# ~/farsite-devAPI/src/farsiteutils_v2.py in __setup(self)
#     309     def __setup(self):
#     310         # setup the database for create/append
# --> 311         self.__setup_dbtable()
#     312
#     313     def __setup_dbtable(self):
#
# ~/farsite-devAPI/src/farsiteutils_v2.py in __setup_dbtable(self)
#     314         # print('Database interaction not yet implemented. Use pickle file for dataframes instead!')
#     315
# --> 316         self.db = Database_v2(self.fp, self.description)
#     317
#     318     def __selectPerimeter(self, inputData: dict):
#
# ~/farsite-devAPI/src/farsiteutils_v2.py in __init__(self, fp, description)
#      89
#      90         try:
# ---> 91             dftable = pd.read_pickle(self.fp.dfpath)
#      92             change_username_jovyan(dftable, 'filepath')
#      93         except FileNotFoundError:
#
# /usr/local/lib/python3.8/dist-packages/pandas/io/pickle.py in read_pickle(filepath_or_buffer, compression, storage_options)
#     177     """
#     178     excs_to_catch = (AttributeError, ImportError, ModuleNotFoundError, TypeError)
# --> 179     with get_handle(
#     180         filepath_or_buffer,
#     181         "rb",
#
# /usr/local/lib/python3.8/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     866         else:
#     867             # Binary mode
# --> 868             handle = open(handle, ioargs.mode)
#     869         handles.append(handle)
#     870
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/jovyan/data/dftable_06032023.pkl'

# %% [markdown]
# ## Plot model outputs

# %%
fig, ax = plt.subplots(1,1, figsize=(4,4), dpi=200)

plot_geometry(reproject_geom(ignition), ax=ax, color='red')
for i in range(tfin-1):
#     model_geom = no_ds_outputs[i]
#     plot_geometry(reproject_geom(model_geom), ax=ax, label=timestamp, color=(0,0,0,1-i/10))
        
    geom, timestamp = get_observation(description, i)
    plot_geometry(reproject_geom(geom), ax=ax, label=timestamp, color=(1,0,0,1-i/10))

    adjusted_geom = adjusted_geom_lst[i]
    # plot_geometry(reproject_geom(adjusted_geom), ax=ax, label=timestamp, color=(0,0,1,1-i/10), ls='--', lw=1)

# Maria boundaries
ax.set_xlim(-13259480.899793554, -13248356.055776488)
ax.set_ylim(4066612.9682816155, 4075471.350794237)

# # Bridge boundaries
# ax.set_xlim(-2.1260e6, -2.1235e6)
# ax.set_ylim(2.0470e6, 2.0485e6)

# River boundaries
# ax.set_xlim(-2.1260e6, -2.1235e6)
# ax.set_ylim(2.0470e6, 2.0485e6)

ctx.add_basemap(ax=ax, source=ctx.providers.OpenStreetMap.Mapnik)
ax.set_title('No data assimilation output')
# Out:
# Text(0.5, 1, 'No data assimilation output')

# %%
wdlstfig, ax = plt.subplots(1,1, figsize=(4,4), dpi=200)

plot_geometry(reproject_geom(ignition), ax=ax, color='red')
for i in range(tfin-1):
#     model_geom = no_ds_outputs[i]
    # plot_geometry(reproject_geom(model_geom), ax=ax, label=timestamp, color=(0,0,0,1-i/10))
        
    geom, timestamp = get_observation(description, i)
    plot_geometry(reproject_geom(geom), ax=ax, label=timestamp, color=(1,0,0,1-i/tfin))

    adjusted_geom = adjusted_geom_lst[i]
    plot_geometry(reproject_geom(adjusted_geom), ax=ax, label=timestamp, color=(0,0,0,1-i/tfin), ls='--', lw=1)

# Maria boundaries
# ax.set_xlim(-13259480.899793554, -13248356.055776488)
# ax.set_ylim(4066612.9682816155, 4075471.350794237)

# # Bridge boundaries
# ax.set_xlim(-2.1260e6, -2.1235e6)
# ax.set_ylim(2.0470e6, 2.0485e6)

# River boundaries
# ax.set_xlim(-2.1260e6, -2.1235e6)
# ax.set_ylim(2.0470e6, 2.0485e6)

ctx.add_basemap(ax=ax, source=ctx.providers.OpenStreetMap.Mapnik)
ax.set_title('With data assimilation')
# Out:
# Text(0.5, 1, 'With data assimilation')
